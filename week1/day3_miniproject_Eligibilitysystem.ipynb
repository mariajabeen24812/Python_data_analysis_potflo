# %% [markdown]
# ### MINI PROJECT 💼
# ## Player Eligibility system

# %% [markdown]
# ## make a mini project on player eligiblility system on sports

# %%
name = input('Enter your name:')
print(f'Hello {name}')
print('There are five games:')

print('1- Football \n2- Hockey \n3- Cricket \n4- Badminton \n5-Table Tannis \n which game do you want to apply enter your game')
game = (input('Enter your game:'))
game = game.title()
print('your game :' , game)

if(game == 'Football' or game =='Cricket' or game == 'Hockey' or game == 'Table Tennis' or game == 'Badminton' ):
    print('Eligiblility criteria set according to your age so enter your age :')
    age = int(input('Enter your age'))
    print('your age :' , age)
    if(age >= 10 and age <= 35 and game == 'Football'):
        print(f'your are eligible in this  {game} ')
    elif(age >= 12 and age <= 40 and game =='Cricket'):
        print(f'your are eligible in this  {game} ')
    elif(age >= 12 and age <= 35 and game == 'Hockey'):
        print(f'your are eligible in this  {game} ')
    elif(age >= 10 and age <= 35 and game == 'Badminton'):
        print(f'your are eligible in this  {game} ')
    elif(age >= 10 and age <= 35 and game == 'Table Tennis'):
        print(f'your are eligible in this  {game} ')
    else:
        print(f'you are not fit in  {game} game')
else: 
    print('Invalid game')
# Out:
# Hello Ali
# There are five games:
# 1- Football
# 2- Hockey
# 3- Cricket
# 4- Badminton
# 5-Table Tannis
#  which game do you want to apply enter your game
# your game : Football
# Eligiblility criteria set according to your age so enter your age :
# your age : 45
# you are not fit in  Football game
