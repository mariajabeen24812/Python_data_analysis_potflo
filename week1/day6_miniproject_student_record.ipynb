# %% [markdown]
# ### MINI PROJECT 💼
# ## Student Management System

# %% [markdown]
# 1. Add Student
# 2. Show All Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Calculate Grade
# 7. Check Pass/Fail
# 8. Search by Department
# 9. Show Student Count
# 10. Show Unique Cities
# 11. Show Departments
# 12. Exit

# %%
# display menue
print('================================ \n STUDENT MANAGEMENT SYSTEM\n================================\n 1. Add Student \n 2. Show All Students\n 3. Search Student \n 4. Update Student \n 5. Delete Student \n 6. Calculate Grade \n 7. Check Pass/Fail \n 8. Search by Department \n 9. Show Student Count \n 10. Show Unique Cities \n 11. Show Departments \n 12. Exit')
students = {}
# cities = set()
# Out:
# ...
#  STUDENT MANAGEMENT SYSTEM
# ...
#  1. Add Student
#  2. Show All Students
#  3. Search Student
#  4. Update Student
#  5. Delete Student
#  6. Calculate Grade
#  7. Check Pass/Fail
#  8. Search by Department
#  9. Show Student Count
#  10. Show Unique Cities
#  11. Show Departments
#  12. Exit

# %%
# add student 
chose = int(input('Enter a number:'))
if(chose == 1):
    num = int(input('How many student do you entered :'))
    for i in range(num):   
        stu_id = int(input('Enter students id'))
        stu_name = input('Enter students name')
        stu_marks = int(input('Enter students marks'))
        stu_city = input('Enter student city')
        stu_age = int(input('Enter students age'))
        stu_department = input('Enter student department')
        students[stu_id] = {
                        'name' : stu_name,

                        'age' : stu_age,
                        'department' : stu_department,
                        'marks' : stu_marks,
                        'city' : stu_city
                    }
            # show all students        
elif(chose == 2):
    print('Show all students\n ', students)

elif(chose == 3):
    search_stu = int(input('Enter student roll no:'))
    print(f'student {search_stu} : {students[search_stu]}')
elif(chose == 4):
    num = int(input('How many student do you want to update :'))
    for i in range(num):   
        stu_id = int(input('Enter students id'))
        stu_name = input('Enter students name')
        stu_marks = int(input('Enter students marks'))
        stu_city = input('Enter student city')
        stu_age = int(input('Enter students age'))
        stu_department = input('Enter student department')
        students[stu_id] = {
                            'name' : stu_name,
                            'age' : stu_age,
                            'department' : stu_department,
                            'marks' : stu_marks,
                            'city' : stu_city
                        }
elif(chose == 5):
    num = int(input('How many student do you want to delete :'))
    for i in range(num):   
        stu_id = int(input('Enter students id'))
        students.pop(stu_id)
# calculate grades
elif(chose == 6):

                stu_id = int(input('Enter student id: '))
                marks = students[stu_id]['marks']
                if(marks >= 90):
                    print('Grade A+')
                elif(marks >= 80 and marks <= 89 ):
                    print('Grade A')
                elif(marks >= 70 and marks <= 79 ):
                    print('Grade B')
                elif(marks >= 60 and marks <= 69 ):
                    print('Grade C')
                elif(marks >= 50 and marks <= 59 ):
                    print('Grade D') 
                elif(marks >= 40 and marks <= 49 ):
                        print('Grade E') 
                else:
                    print('Grade F')
# check fail or pass
elif(chose == 7):
    stu_id = int(input('Enter student id: '))
    marks = students[stu_id]['marks']
    if(marks >= 40 ):
        print('you are PASS')
    else:
        print('you are FAIL')
# search by department
elif(chose == 8):
    department = input('Enter student department:')
    for key , values in students.items():
        if values['department'] == department:
            print('your student', key,values)

# count student
elif(chose == 9):
    print(len(students) )
# show unique cities
# elif(chose == 10):
#     cities = ()
#     for key , values in students.items():
#         cities.add(values['city'])
#     print(cities)
# elif(chose == 10):
#     cities = {}

#     for key, values in students.items():
#         print(students.union([key][values]['city']))

#     print('Unique cities:', cities)                  
#     print(name.union(marks))
# elif(chose == 10):
#     cities = {values['city'] for values in students.values()}
#     print(cities)
    # print('Unique cities:', cities)
 # show department
elif(chose == 11):
    stu_id = int(input('Enter student id: '))
    department = students[stu_id]['department']
    print(f'{stu_id} has {department} department')
elif(chose == 12):
    exit()
else:
    print('you entered Invalid number')
# Out:
# set()

# %%
city = ()
print(type(city))
# Out:
# <class 'tuple'>
