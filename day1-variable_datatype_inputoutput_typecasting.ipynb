# %% [markdown]
# # 🐍 Day 1 — Python Basics
#
# ## 📌 Today's Concepts
# 1. Variables
# 2. Data Types
# 3. Input and Output
# 4. Type Casting
# 5. Arithmetic Operators

# %% [markdown]
# ##  Variables and Data Type

# %%
# Q1. Ek product ka naam, category aur price,quantity,discount_amount variables mein store karo.
product_name = 'Camera'
category = 'Electronic'
quantity = 2
price = 6000
discount_amount = 200

# %%
# Q2. Ek company ke:employee count,average salary,active status
# variables mein store karo aur type() se data types check karo.
total_emp = 20
average_salary = 50000.0
is_active = True
print("data type of total_employee", type(total_emp))
print("data type of average salary" , type(average_salary))
print("data type of is_active",type(is_active))
# Out:
# data type of total_employee <class 'int'>
# data type of average salary <class 'float'>
# data type of is_active <class 'bool'>

# %%
# Q3. Ek sales transaction ke liye ye variables banao:product,quantity,unit price,total_sales calculate karo.
product = 'shirt'
quantity = 10
unit_price = 500
total_sales = unit_price * quantity
print(f'Total sale {total_sales}')
# Out:
# Total sale 5000

# %% [markdown]
# ## Input Output and Type Casting

# %%
# Q4-User se product name aur price input lo aur dono print karo.
product_name = input("Enter your product name : ")
price = int(input('Enter your product price: '))
print(f"product name : {product_name}")
print(f"price : {price}")
# Out:
# product name : camera
# price : 520

# %%
# Q5. User se quantity input lo. Usay int mein convert karo aur type check karo.
product_qty = input('Enter your Product quantity : ')
products_qty = int(product_qty)
print(type(products_qty))
# Out:
# <class 'int'>

# %%
# Q6. User se product price input lo. Usay float mein convert karo.
product_name = input("Enter your product name : ")
price = int(input('Enter your product price: '))
float_price = float(price)
print(type(float_price))
# Out:
# <class 'float'>

# %%
# Q7. User se quantity aur price lo aur total sales calculate karo.
quantity = int(input('Enter your product quantity : '))
price = int(input('Enter your product price : '))
total_sales = quantity * price
print(f'total price of product {total_sales}')
# Out:
# total price of product 5000
